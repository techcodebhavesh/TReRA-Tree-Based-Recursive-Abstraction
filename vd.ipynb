# %%
from ragatouille import RAGPretrainedModel
RAG = RAGPretrainedModel.from_pretrained("colbert-ir/colbertv2.0")
# Out:
# [Jan 25, 16:50:57] Loading segmented_maxsim_cpp extension (set COLBERT_LOAD_TORCH_EXTENSION_VERBOSE=True for more info)...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 from ragatouille import RAGPretrainedModel
# ----> 2 RAG = RAGPretrainedModel.from_pretrained("colbert-ir/colbertv2.0")
#
# File c:\Users\bhave\AppData\Local\Programs\Python\Python312\Lib\site-packages\ragatouille\RAGPretrainedModel.py:71, in RAGPretrainedModel.from_pretrained(cls, pretrained_model_name_or_path, n_gpu, verbose, index_root)
#      59 """Load a ColBERT model from a pre-trained checkpoint.
#      60
#      61 Parameters:
#    (...)
#      68     cls (RAGPretrainedModel): The current instance of RAGPretrainedModel, with the model initialised.
#      69 """
#      70 instance = cls()
# ---> 71 instance.model = ColBERT(
#      72     pretrained_model_name_or_path, n_gpu, index_root=index_root, verbose=verbose
#      73 )
#      74 return instance
#
# File c:\Users\bhave\AppData\Local\Programs\Python\Python312\Lib\site-packages\ragatouille\models\colbert.py:84, in ColBERT.__init__(self, pretrained_model_name_or_path, n_gpu, index_name, verbose, load_from_index, training_mode, index_root, **kwargs)
#      81     self.config.root = self.index_root
#      83 if not training_mode:
# ---> 84     self.inference_ckpt = Checkpoint(
#      85         self.checkpoint, colbert_config=self.config
#      86     )
#      87     self.base_model_max_tokens = (
#      88         self.inference_ckpt.bert.config.max_position_embeddings
#      89     ) - 4
#      91 self.run_context = Run().context(self.run_config)
#
# File c:\Users\bhave\AppData\Local\Programs\Python\Python312\Lib\site-packages\colbert\modeling\checkpoint.py:19, in Checkpoint.__init__(self, name, colbert_config, verbose)
#      18 def __init__(self, name, colbert_config=None, verbose:int = 3):
# ---> 19     super().__init__(name, colbert_config)
#      20     assert self.training is False
#      22     self.verbose = verbose
#
# File c:\Users\bhave\AppData\Local\Programs\Python\Python312\Lib\site-packages\colbert\modeling\colbert.py:24, in ColBERT.__init__(self, name, colbert_config)
#      21 super().__init__(name, colbert_config)
#      22 self.use_gpu = colbert_config.total_visible_gpus > 0
# ---> 24 ColBERT.try_load_torch_extensions(self.use_gpu)
#      26 if self.colbert_config.mask_punctuation:
#      27     self.skiplist = {w: True
#      28                      for symbol in string.punctuation
#      29                      for w in [symbol, self.raw_tokenizer.encode(symbol, add_special_tokens=False)[0]]}
#
# File c:\Users\bhave\AppData\Local\Programs\Python\Python312\Lib\site-packages\colbert\modeling\colbert.py:39, in ColBERT.try_load_torch_extensions(cls, use_gpu)
#      36     return
#      38 print_message(f"Loading segmented_maxsim_cpp extension (set COLBERT_LOAD_TORCH_EXTENSION_VERBOSE=True for more info)...")
# ---> 39 segmented_maxsim_cpp = load(
#      40     name="segmented_maxsim_cpp",
#      41     sources=[
#      42         os.path.join(
#      43             pathlib.Path(__file__).parent.resolve(), "segmented_maxsim.cpp"
#      44         ),
#      45     ],
#      46     extra_cflags=["-O3"],
#      47     verbose=os.getenv("COLBERT_LOAD_TORCH_EXTENSION_VERBOSE", "False") == "True",
#      48 )
#      49 cls.segmented_maxsim = segmented_maxsim_cpp.segmented_maxsim_cpp
#      51 cls.loaded_extensions = True
#
# File c:\Users\bhave\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\cpp_extension.py:1309, in load(name, sources, extra_cflags, extra_cuda_cflags, extra_ldflags, extra_include_paths, build_directory, verbose, with_cuda, is_python_module, is_standalone, keep_intermediates)
#    1217 def load(name,
#    1218          sources: Union[str, List[str]],
#    1219          extra_cflags=None,
#    (...)
#    1227          is_standalone=False,
#    1228          keep_intermediates=True):
#    1229     """
#    1230     Load a PyTorch C++ extension just-in-time (JIT).
#    1231
#    (...)
#    1307         ...     verbose=True)
#    1308     """
# -> 1309     return _jit_compile(
#    1310         name,
#    1311         [sources] if isinstance(sources, str) else sources,
#    1312         extra_cflags,
#    1313         extra_cuda_cflags,
#    1314         extra_ldflags,
#    1315         extra_include_paths,
#    1316         build_directory or _get_build_directory(name, verbose),
#    1317         verbose,
#    1318         with_cuda,
#    1319         is_python_module,
#    1320         is_standalone,
#    1321         keep_intermediates=keep_intermediates)
#
# File c:\Users\bhave\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\cpp_extension.py:1745, in _jit_compile(name, sources, extra_cflags, extra_cuda_cflags, extra_ldflags, extra_include_paths, build_directory, verbose, with_cuda, is_python_module, is_standalone, keep_intermediates)
#    1742 if is_standalone:
#    1743     return _get_exec_path(name, build_directory)
# -> 1745 return _import_module_from_library(name, build_directory, is_python_module)
#
# File c:\Users\bhave\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\cpp_extension.py:2143, in _import_module_from_library(module_name, path, is_python_module)
#    2141 spec = importlib.util.spec_from_file_location(module_name, filepath)
#    2142 assert spec is not None
# -> 2143 module = importlib.util.module_from_spec(spec)
#    2144 assert isinstance(spec.loader, importlib.abc.Loader)
#    2145 spec.loader.exec_module(module)
#
# File <frozen importlib._bootstrap>:813, in module_from_spec(spec)
#
# File <frozen importlib._bootstrap_external>:1288, in create_module(self, spec)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# ImportError: DLL load failed while importing segmented_maxsim_cpp: The specified module could not be found.

# %%
# ...existing code...
with open("D:/PDF_CONNECT/Processing DPDF_CONNECTMM-0211-02 -.txt", "r", encoding="utf-8") as f:
    full_document = f.read()

RAG.index(
    collection=[full_document],
    index_name="Miyazaki-123",
    max_document_length=180,
    split_documents=True,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 with open("D:/PDF_CONNECT/Processing DPDF_CONNECTMM-0211-02 -.txt", "r", encoding="utf-8") as f:
#       3     full_document = f.read()
# ----> 5 RAG.index(
#       6     collection=[full_document],
#       7     index_name="Miyazaki-123",
#       8     max_document_length=180,
#       9     split_documents=True,
#      10 )
#
# NameError: name 'RAG' is not defined
